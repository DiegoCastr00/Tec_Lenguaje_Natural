# %%
import re
import random

def get_response(user_input):
    split_message = re.split(r'\s|[,:;.?-_]\s*', user_input.lower())
    response = check_all_messages(split_message)
    return response

def message_probability(user_message, recognized_words, single_response=False, required_word=[]):
    message_certainty = 0
    has_required_words = True

    for word in user_message:
        if word in recognized_words:
            message_certainty += 1
    percentage = float(message_certainty) / float(len(recognized_words))

    for word in required_word:
        if word not in user_message:
            has_required_words = False
            break
    if has_required_words or single_response:
        return int(percentage * 100)
    else:
        return 0

def check_all_messages(message):
    highnest_prob = {}

    def response(bot_response, list_of_words, single_response=False, required_words=[]):
        nonlocal highnest_prob
        if isinstance(bot_response, list):
            for response_option in bot_response:
                response(response_option, list_of_words, single_response, required_words)
        else:
            highnest_prob[bot_response] = message_probability(message, list_of_words, single_response, required_words)

    response(['Hola', 'Saludos', '¡Hola de nuevo!'], ['hola', 'klk', 'saludos', 'buenas'], single_response=True)
    response('Estoy bien y tú?', ['como', 'estas', 'va', 'sientes'], required_words=['como'])
    response('Es una placer', ['gracias', 'te lo agradezco', 'thanks'], single_response=True)
    response('Pero no se en donde vives, me puedes dar un lugar de referencia',['vivo','región','localidad'], required_words=['mi'])
    response(local(),['vivo','cerca','región'], single_response=True)
    response(ejercicio(),['ejercicio','entrenamiento'], single_response=True)
    response(concentracion(),['concentrarme','consentracion','cocentración','consentrarse'], single_response=True)
    response(lluvioso(),['lluvioso', 'lluvia','lluviosa'], single_response= True)
    response(fiesta(),['fiesta', 'celebracion','celebración'], single_response= True)
    response(cena(),['romantica', 'romantica','romance'], single_response= True)
    response(clasica(),['clasica','clásica'], required_words=['musica','música'])
    response(mananas(),['despertar', 'empezar','comnezar','animo','animada','buena'],required_words=['mañana'])
    response(viaje(),['carretera'], required_words= ['viaje'])
    response(celebrar(),['logro', 'meta','importante','significativo'], single_response= True)
    best_match = max(highnest_prob, key=highnest_prob.get)
    return unknown() if highnest_prob[best_match] < 1 else best_match

def unknown():
    response = ['¿Puedes decirlo de nuevo? ', 'No estoy seguro de lo que quieres', 'Búscalo en Google a ver qué tal'][random.randrange(3)]
    return response

def local ():
    response = ['¿Te gustaría descubrir bandas locales emergentes o las más establecidas?',
                'Hay talento local en diversos géneros. ¿Algo específico en mente?',
                'Claro, ¿qué tal si escuchas a banda1 para empezar?',
                '¿Conoces a artista1 ? Su música géneroX podría interesarte.',
                'Claro, Festival1 es una excelente oportunidad para descubrir nuevos talentos. ¡No te lo pierdas!',
                'En tu localidad banda1 ha estado generando mucho entusiasmo últimamente.',
                '¡Saludos! ¿Te gustaría una mezcla de diferentes géneros locales en una lista de reproducción?',
                'Te recomendaría echar un vistazo a Festival1 para descubrir nuevos talentos de la ciudad.',
                '¿Has escuchado el último sencillo de artista1 ? ¡Es sumamente popular!',
                'Claro, ¿qué opinas de géneroX ? Hay algunas propuestas locales increíbles.',
                'Claro, ¿algún género en particular que te llame la atención? Puedo personalizar las recomendaciones.',
                'La escena del géneroX está en auge, y banda1 es una banda que no querrás perderte.',
                'Si te gusta el pop, artistas locales como artista1 están en la cima de las listas de reproducción locales.',
                'En tu zona, el reguetón ha ganado mucha popularidad en los últimos meses. Artistas locales como artista1 lideran la escena.',
                '¿Buscas algo más relajado? La música acústica de artistas locales como Çity Serenades"podría ser perfecta para ti.',
                '¡Claro!, los artistas más escuchados en tu ciudad son artista1, artista2, artista3',
                'Claro, al parecer el género más escuchado en tu zona es géneroX',
                'Por supuesto, en tu ciudad los álbumes más vendidos en tu ciudad son álbum1, álbum2,álbum3',
                'Claro, Los artistas en tendencia de tu ciudad son artista1, artista2, artista3',
                'Por supuesto, ¿Te gustaría explorar música local de artistas solistas o bandas?'][random.randrange(20)]
    return response

def ejercicio():
    response = ['¿Qué te parece la música de los años 80? Sus ritmos animados y nostálgicos podrían ser una opción divertida para tu sesión de ejercicio.',
                'La música de videojuegos a menudo tiene composiciones épicas y motivadoras que podrían ser ideales para tu rutina de ejercicios.',
                'Algunas personas encuentran que la música clásica con un tempo rápido es perfecta para concentrarse durante el ejercicio, ¿Qué te parece explorar esta opción?',
                'Si buscas energía intensa, el metal pesado es considerado un género que eleva el ritmo cardiaco',
                'Te puedo recomendar el pop rock, te proporcionará una mezcla de melodías pegajosas y energía que podría mejorar tu rendimiento durante el ejercicio.',
                '¡Claro!, el techno te ofrece una experiencia sonora futurista que puede ser ideal para mantener un ritmo constante durante tu actividad física',
                '¡Saludos!, por supuesto, algunas personas encuentran que el pop energético es ideal para impulsar su rendimiento físico. ¿Has considerado probarlo?',
                'La música latina, con sus ritmos vibrantes, puede añadir un toque emocionante a tu sesión de entrenamiento. ¿Te animarías a probarla?',
                '¡Hola!, muchos optan por la música hip-hop como de Ye, durante el ejercicio debido a sus ritmos intensos y letras motivadoras. ¿Te gusta ese estilo?',
                '¡Seguro!, el R&B contemporáneo puede ofrecer un equilibrio único entre ritmos suaves y energía suficiente para mantener el impulso durante el entrenamiento.',
                'El indie pop con sus melodías ligeras, pero atractivas podría ser una opción refrescante para tu sesión de ejercicio. ¿Lo has probado alguna vez?',
                '¿Te interesaría probar con el country pop?, este ofrece ritmos alegres y letras optimistas que podrían animarte durante tu rutina de ejercicio.',
                'La música instrumental, como la electrónica ambiental, puede proporcionar un fondo sonoro sin distracciones para tu entrenamiento. ¿Te gustaría probarla?',
                'Si te interesa motivarte el rap con sus letras motivadoras y ritmos intensos es una opción popular para muchos durante el ejercicio.',
                'Te recomiendo el ska, con sus ritmos festivos y enérgicos, podría ser una opción divertida y diferente para tu rutina de ejercicios. ¿Te animarías a probarlo?',
                'El género dance y la música techno son conocidos por sus ritmos rápidos, ideales para sesiones de ejercicio intenso.',
                '¡Seguro!, El reggaeton es una opción animada que puede ayudarte a mantenerte activo durante el entrenamiento.',
                'He encontrado que la música de bandas sonoras épicas puede brindar una sensación cinematográfica que impulsa tu motivación durante el entrenamiento.',
                '¡Seguro!, la música soul y funk pueden agregar un toque de groove y ritmo a tu rutina de ejercicios.',
                'La música folk, con su simplicidad y autenticidad, puede ser una opción refrescante para algunos usuarios durante el ejercicio.'][random.randrange(20)]
    return response

def concentracion ():
    response = ['La música instrumental, como el jazz, es ideal para mantener la concentración.',
                'Música clásica contemporánea, como la minimalista, favorece la concentración.',
                'Los géneros tranquilos son un fuerte aliado como el jazz',
                'La música ambiental con sonidos de piano es suave y no intrusiva.',
                'La música indie tranquila puede ser un compañero ideal para el trabajo.',
                'Géneros de música neoclásica ofrecen una experiencia auditiva reflexiva que promueve la concentración.',
                'El soft rock brinda un sonido constante sin ser abrumador.',
                'La musica oriental como la japonesa resulta ser una buena opción.',
                'La música indie instrumental ofrece una mezcla única de creatividad y calma.',
                'El soul instrumental puede añadir un toque de elegancia a tu espacio de trabajo.',
                'Considera géneros como el ambient techno para una experiencia auditiva envolvente pero no invasiva.',
                'Las mezclas de electronica calmada son conocidas por mejorar la concetración.',
                'Música de piano suave puede ser una opción clásica para concentrarse.',
                'El neoclásico combina elementos clásicos con un toque contemporáneo para concentrarse.',
                'Electrónica instrumental: Los ritmos electrónicos sin letras pueden mantener tu mente enfocada en la tarea.',
                'Sonidos naturales, como música de lluvia o pájaros, pueden crear un ambiente para concentrarse.',
                'Escuchar álbumes conceptuales puede mantener una continuidad que favorece la concentración.',
                'Géneros de música retro, como synthwave, pueden ser nostálgicos pero no distraen.',
                'Géneros lounge, como el bossa nova, pueden tener un ritmo suave para trabajar.',
                'El ambient pop o el dream pop son opciones sutiles que no distraen demasiado.'][random.randrange(20)]
    return response

def lluvioso ():
    response = ['Sin duda, el género perfecto para un día lluvioso es el jazz suave, crea una atmósfera relajante.',
                'Pienso que probar con música ambiental o chillout, es una manera perfecta para complementar la lluvia de manera tranquila.',
                '¡Claro!, el indie folk o el acoustic son opciones geniales para acompañar la melancolía de la lluvia.',
                'Deberías considerar escuchar música clásica, es perfecta para esos días reflexivos y lluviosos.',
                '¿Has probado con el blues? La combinación de sus tonos melancólicos y emotivos puede ser ideal.',
                'Claro, para un toque más moderno, la música electrónica downtempo puede ser la elección acertada.',
                'Te recomiendo probar con el género soul o el R&B suave, son excelentes opciones para un día lluvioso.',
                'Poco conocido, pero el género trip-hop tiene una mezcla única que podría encajar.',
                'Encontré que entre las mejores opciones está la música de piano instrumental, crea una sensación calmante, ¡perfecta para la lluvia!',
                'El folk americano, tiene letras melódicas que pueden capturar la esencia de un día lluvioso.',
                'Uno de los estilos musicales más ocultos, pero excelentes, es el bossa nova, la cual brinda un ambiente relajado y alegre, ideal para contrarrestar la lluvia.',
                'Si te entristece la lluvia, seguro debes probar con algo más animado, el reggae suave puede ser la elección perfecta.',
                '¡Claro!, el lo-fi hip-hop es famoso por su calma, ¡ideal para acompañar el sonido de la lluvia!',
                'El género ambiental minimalista puede sumergirte en una experiencia tranquila y reflexiva.',
                '¿Qué tal un poco de música clásica contemporánea para agregar un toque moderno a tu día lluvioso?',
                'Si tu misión es sumergirte en el momento, te recomiendo probar con el folk psicodélico.',
                'Si buscas que el momento sea nostálgico, prueba con la música country suave, que puede ser perfecto para un día lluvioso.',
                'El soft rock de los años 70 tiene un toque nostálgico que puede encajar bien con la lluvia.',
                '¿Qué te parece el post-rock? Es interesante por sus estructuras instrumentales, las cuales pueden ser fascinantes en días lluviosos.',
                'Si buscas algo más alternativo, el dream pop crea una atmósfera etérea y soñadora que complementa bien la lluvia.'][random.randrange(20)]
    return response

def fiesta ():
    response= ['El rock clásico siempre es una opción segura para animar a la multitud.',
                'Un set de música latina, con salsa y merengue, hará que todos se paren a bailar.',
                'El pop actual tiene ritmos pegajosos que seguramente harán que todos se levanten y bailen.',
                'La música de carnaval con sus ritmos festivos es perfecta para una fiesta llena de alegría.',
                'La música electrónica, con sus beats enérgicos, es perfecta para crear un ambiente festivo.',
                'Las canciones latinas y caribeñas tienen ese ritmo contagioso que hará que todos quieran bailar.',
                'Los éxitos del momento en el género urbano son perfectos para mantener a los miembros de la fiesta entretenidos',
                'Para una opción más clásica, la música disco siempre ha sido un éxito en las pistas de baile. ¿Te gustaría algunas recomendaciones de clásicos disco?',
                '¡Saludos! Si buscas que la fiesta esté llena de ritmo y alegría, la música latina, como el reggaetón y la salsa, podría ser la elección perfecta.',
                'Si buscas un ambiente lleno de diversión y nostalgia, la música disco de los años 70 y 80 siempre es una opción acertada. ¿Te gustaría una selección de clásicos de la esas épocas?',
                '¡El reggaetón tiene ritmos contagiosos que seguramente pondrán a todos a bailar!',
                'La fusión de pop y rock suele ser un éxito. Puedo recomendarte una lista de reproducción con esos elementos para mantener a todos animados.',
                'Salsa y merengue son opciones clásicas para una fiesta llena de movimiento.',
                'Un toque de música clásica o jazz suave puede ser elegante y animado.',
                'Para una fiesta temática, prueba con música de los años 70 o 90.',
                '¿Qué te parece una lista de reproducción con los últimos éxitos pop y rock?',
                '¡Para animar la fiesta, te sugiero una mezcla de música dance y electrónica!',
                '¿Qué te parece una lista de reproducción con los éxitos actuales de las listas de música pop?',
                'Si buscas algo versátil, el pop contemporáneo tiene éxitos que todos disfrutarán.',
                'Un mix de hits de los 80 y 90 puede generar un ambiente nostálgico y divertido.'][random.randrange(20)]
    return response

def cena():
    response = ['Una excelente elección sería optar por baladas suaves y melódicas para crear un ambiente romántico.',
                'La música instrumental suave, como el jazz o el piano, puede ser perfecta para una cena romántica.',
                '¿Qué te parece una playlist de música clásica tranquila para esa ocasión especial?',
                'Podrías considerar música contemporánea con letras románticas para darle un toque moderno.',
                'Si deseas establecer una atmósfera romántica y relajada, elige géneros como el R&B o el soul',
                'Seguro, te recomiendo probar con música acústica, como canciones con guitarra suave, para crear un ambiente íntimo.',
                'Seguro, ¿Has pensado en música latina suave, como boleros o bossa nova? Son excelentes para una cena romántica',
                'Si buscas música solamente para el ambiente te recomiendo chillout, la cual puede ser una opción tranquila y romántica para tu cena.',
                'Las baladas clásicas siempre son una apuesta segura para una cena romántica y nostálgica.',
                '¿Has considerado música folk suave o indie para un toque más relajado pero romántico?',
                'Estoy seguro de que debes explorar géneros como el blues suave para crear un ambiente íntimo.',
                'La música country en general es una elección encantadora para una cena romántica.',
                '¿Qué opinas de una selección de canciones de artistas pop con letras románticas?',
                'Seguramente el reggae suave o el ska pueden agregar un toque único y relajado a tu cena romántica.',
                'Una de las mejores épocas de las canciones de amor clásicas, es la década de 1980, las cuales podrían ser la elección perfecta.',
                'Una opción algo arriesgada, pero interesante, es la música electrónica suave y ambiental para una cena romántica moderna',
                'La música de películas románticas, como bandas sonoras, puede ser una opción emotiva.',
                '¿Has pensado en música indie-folk para una cena romántica con un ambiente más bohemio?',
                'Te puedo crear una playlist de canciones de amor en varios idiomas, creo que podría ser una opción romántica y diversa.',
                '¿Qué te parece la música suave de artistas contemporáneos que se centran en letras románticas?'][random.randrange(20)]
    return response

def clasica():
    response = ['Si buscas algo majestuoso, escucha "La Marcha Turca"de Mozart, una pieza llena de energía.',
                'Considera escuchar .El lago de los cisnes"de Tchaikovsky para sumergirte en la belleza que represeta el ballet clásico.',
                'La "Sinfonía No. 9"de Beethoven, conocida como la Çoral", es una experiencia épica que no te puedes perder, tambien es una de las piezas mas conocidas.',
                'Si lo tuyo es algo más íntimo, prueba las "Gymnopédies"de Erik Satie, piezas minima listas y emotivas.',
                'Adagio para cuerdas"de Barber es reconocido por su profunda expresión emocional.',
                '¿Has escuchado "Las Cuatro Estaciones"de Antonio Vivaldi? Cada estación tiene su propio encanto único.',
                '¿Te gustaría algo más contemporáneo? Escucha Çoncierto para Violín"de Philip Glass.',
                '"Valses Nobles y Sentimentales"de Maurice Ravel es una experiencia auditiva encantadora.',
                'Si buscas algo relajante, la "Gymnopédie No. 1"de Erik Satie es perfecta para un ambiente tranquilo.',
                'Ave María"de Franz Schubert es una pieza conmovedora y espiritual.',
                'Te sugiero escuchar Çanción de Cuna"de Brahms, una pieza serena y encantadora.',
                '¿Has explorado la majestuosidad de .El lago de los cisnes"de Tchaikovsky? Es una obra maestra.',
                'Para algo romántico, prueba Romeo y Julieta"de Prokofiev; es una obra maestra del siglo XX',
                '"Sinfonía No. 5"de Beethoven, con su famoso motivo inicial, es universalmente reconocida.',
                'La "Pavane"de Fauré es una pieza encantadora y nostálgica para disfrutar en calma.',
                'Çanon en Re Mayor"de Johann Pachelbel es una elección atemporal y apacible.',
                'Si buscas algo relajante, te recomendaría Çlair de Lune"de Claude Debussy.',
                'Para algo más dramático, te sugiero Réquiem"de Wolfgang Amadeus Mozart.',
                'Concierto de Aranjuez"de Joaquín Rodrigo ofrece una experiencia clásica con toques españoles.',
                '¿Te gustaría algo más enérgico? Prueba Ïn the Hall of the Mountain King"de Grieg.'][random.randrange(20)]
    return response

def  mananas():
    response = ['Te sugiero un playlist de música pop enérgica para darle un impulso positivo a tu día.',
                'Un mix de música electrónica con ritmos animados podría ser la elección perfecta para energizarte.',
                'Para una mañana tranquila pero positiva, la música folk puede ser una excelente elección.',
                'Música acústica relajante o suaves notas de jazz son excelentes para una mañana tranquila.',
                'Puedo sugerirte un mix de música indie optimista para animar tu mañana.',
                '¡Una dosis de música pop alegre siempre es perfecta para comenzar el día con energía positiva!',
                'Playlist1 es una playlist con éxitos actuales para comenzar bien el día.',
                '¿Has considerado música tropical o reggae para darle un toque energético a tu día?',
                'La calidez de la música acústica puede crear un ambiente amigable y agradable para empezar el día.',
                'Explora canciones como Canción1 con letras motivadoras que te impulsen a enfrentar el día con confianza.',
                'Escucha música clásica con piezas inspiradoras que te llenarán de energía positiva.',
                'La música dance tiene la capacidad de elevar tu energía desde el principio del día.',
                'Considera escuchar alguna playlist de Playlist1 con canciones inspiradoras y motivadoras.',
                'Las canciones de artistas como artista1 o artista2 tienen un ritmo animado y positivo.',
                'Música de bandas sonoras de películas alegres puede ser una opción para un despertar positivo.',
                'Explora las últimas canciones de tus artistas pop favoritos para mantenerte actualizado.',
                'Las canciones de pop-rock con ritmos positivos pueden impulsar tu día desde el principio.',
                'La música ambiental puede ofrecer un despertar suave y sin sobresaltos.',
                'La música instrumental, como el piano suave, puede ser una opción armoniosa para despertar.',
                '¿Qué te parecería comenzar el día con las canciones más recientes de la escena pop? Mantente al día con los éxitos actuales.'][random.randrange(20)]
    return response

def viaje():
    response = ['¡Claro!, para un viaje por carretera, podrías disfrutar de una playlist de música indie relajante.',
                '¡Qué emocionante! Te recomendaría música pop animada para mantener un buen ambiente durante tu viaje.',
                '¿Has probado con música clásica? Puede ser una opción tranquila y elegante para el camino.',
                '¡Viaje por carretera, ritmo latino! Una lista de reproducción de música latina podría ser perfecta.',
                '¡Seguro!, para una experiencia relajada, la música acústica siempre es una excelente elección.',
                '¿Qué te parece un mix de rock clásico para hacer tu viaje más épico?',
                'Si buscas algo diferente, podrías explorar la música electrónica para darle un toque moderno a tu viaje.',
                'Un poco de jazz suave puede crear una atmósfera agradable mientras conduces, me suena una genial idea.',
                '¡Aventúrate con música folk para una experiencia más cercana a la naturaleza durante tu viaje!',
                'Para mantener la energía alta, una lista de reproducción de música pop actualizada es ideal.',
                '¿Te gustaría probar con música country para darle un toque auténtico a tu viaje?',
                '¡Un viaje más nostálgico con éxitos de los 80 puede ser muy divertido!',
                '¡Seguro!, si buscas relajación, la música ambiental puede ser la compañera perfecta para tu viaje.',
                'Si deseas un momento de impulso extra de energía, el Rock alternativo es excelente para esos momentos de bajones',
                'Si te diriges hacia un nuevo lugar, te recomiendo que te introduzcas a su cultura escuchando música regional de ese lugar',
                'Una playlist de música instrumental puede ser genial para concentrarte en la carretera.',
                '¿Has considerado música internacional? Descubre nuevos sonidos mientras viajas.',
                'Te recomiendo que optes por música soul para una experiencia sonora rica y llena de emociones.',
                '¡Viaje vintage! Prueba con música de los años 60 para un toque retro.',
                '¿Qué te parece la idea de explorar bandas sonoras de películas? A veces, ofrecen una experiencia cinematográfica en el camino.'][random.randrange(20)]
    return response

def celebrar():
    response = ['¡Felicidades por tu logro! Para celebrar, podría sugerir música festiva y alegre que te haga sentir como en una fiesta constante.',
                'Para una celebración con estilo, música jazz suave podría ser una opción encantadora y sofisticada.',
                'Considera ritmos de música electrónica enérgica para reflejar la emoción y la positividad de tu éxito.',
                'La música épica y motivadora puede resaltar la magnitud de tu logro y crear una atmósfera triunfante.',
                'La música rock enérgica y motivadora puede darle a tu celebración un impulso adicional.',
                'Playlist1 tiene una selección de canciones cuidadosamente elegidas para momentos como este.',
                '¿Te gustaría explorar la música de artistas emergentes que también celebran el éxito de formas únicas?',
                '¿Qué te parece una banda sonora de película con temas triunfales?',
                'Melodías de piano inspiradoras para agregar un toque emotivo a la celebración.',
                'Busca listas de reproducción específicas con títulos como Playlist1 que contengan canciones que celebren el éxito.',
                '¿Qué te parece canción1 de artista1 para crear un ambiente optimista?',
                'Una lista de reproducción con los éxitos más recientes para estar a la moda mientras celebras.',
                'canción1 de artista es una opción contagiosa para alegrar el ambiente.',
                '¡Bravo! La música dance podría ser la opción ideal para animar la fiesta y mantener la energía alta.',
                'Te puedo recomendar la música reggae relajada, la cual podría ser la elección perfecta para celebrar con buena vibra.',
                '¡Enhorabuena! Un poco de música soul podría añadir una dosis de emoción y pasión a tu celebración.',
                '¡Increíble logro! Música de piano clásica podría crear un ambiente sofisticado y reflexivo para tu celebración.',
                '¡Felicidades! Podrías considerar música tropical para transportarte a un lugar lleno de alegría y exotismo.',
                '¿Qué opinas de un poco de música hip-hop para agregar un toque urbano y vibrante a la celebración?',
                '¡Enhorabuena por tu éxito! Música indie pop podría ser la elección perfecta para una celebración moderna y chic.'][random.randrange(20)]
    return response

# %%
while True:
    user_input = input('TÚ: ')
   
    if user_input.lower() == 'adios':
        print("BOT: ¡Adios! Es un gusto poder ayudarte :) ")
        break
    #print("TU: " + user_input)
    print("BOT: " + get_response(user_input))
# Out:
# BOT: Hola
# BOT: ¡Seguro!, si buscas relajación, la música ambiental puede ser la compañera perfecta para tu viaje.
# BOT: Búscalo en Google a ver qué tal
# BOT: ¡Adios! Es un gusto poder ayudarte :)
